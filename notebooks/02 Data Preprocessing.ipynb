# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %% [markdown]
# Load Dataset

# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/bank-additional/bank-additional-full.csv",
    sep=";"
)

df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %% [markdown]
# Remove Duplicate Rows

# %%
print("Before:", df.shape)

df = df.drop_duplicates()

print("After :", df.shape)
# Out:
# Before: (41188, 21)
# After : (41176, 21)

# %% [markdown]
# Check Missing Values

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# Encode Target Variable

# %%
df["y"] = df["y"].map({
    "no": 0,
    "yes": 1
})

df["y"].value_counts()
# Out:
# y
# 0    36537
# 1     4639
# Name: count, dtype: int64

# %% [markdown]
# Separate Features and Target

# %%
X = df.drop("y", axis=1)

y = df["y"]

print("Features Shape :", X.shape)
print("Target Shape   :", y.shape)
# Out:
# Features Shape : (41176, 20)
# Target Shape   : (41176,)

# %% [markdown]
# Categorical Columns

# %%
categorical_cols = X.select_dtypes(include="object").columns.tolist()

print(categorical_cols)
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']

# %% [markdown]
# One-Hot Encoding

# %%
X = pd.get_dummies(
    X,
    drop_first=True
)

print("Encoded Features Shape:", X.shape)
# Out:
# Encoded Features Shape: (41176, 53)

# %% [markdown]
# Encoded Dataset

# %%
X.head()
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   56       261         1    999         0           1.1          93.994
# 1   57       149         1    999         0           1.1          93.994
# 2   37       226         1    999         0           1.1          93.994
# 3   40       151         1    999         0           1.1          93.994
# 4   56       307         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  ...  month_may  month_nov  \
# 0          -36.4      4.857       5191.0  ...       True      False
# 1          -36.4      4.857       5191.0  ...       True      False
# 2          -36.4      4.857       5191.0  ...       True      False
# 3          -36.4      4.857       5191.0  ...       True      False
# 4          -36.4      4.857       5191.0  ...       True      False
#
#    month_oct  month_sep  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# ...

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Features :", X_train.shape)
print("Testing Features  :", X_test.shape)

print("Training Target   :", y_train.shape)
print("Testing Target    :", y_test.shape)
# Out:
# Training Features : (32940, 53)
# Testing Features  : (8236, 53)
# Training Target   : (32940,)
# Testing Target    : (8236,)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %% [markdown]
# Final Shapes

# %%
print("X_train :", X_train.shape)
print("X_test  :", X_test.shape)

print("y_train :", y_train.shape)
print("y_test  :", y_test.shape)
# Out:
# X_train : (32940, 53)
# X_test  : (8236, 53)
# y_train : (32940,)
# y_test  : (8236,)

# %% [markdown]
# Saving Data

# %%
import os
import joblib

os.makedirs("../src/data/processed", exist_ok=True)

joblib.dump(X_train, "../src/data/processed/X_train.pkl")
joblib.dump(X_test, "../src/data/processed/X_test.pkl")
joblib.dump(y_train, "../src/data/processed/y_train.pkl")
joblib.dump(y_test, "../src/data/processed/y_test.pkl")

joblib.dump(scaler, "../src/data/processed/scaler.pkl")

print("Processed data saved successfully.")
# Out:
# Processed data saved successfully.

# %%
import joblib

joblib.dump(X.columns.tolist(), "../models/feature_names.pkl")
# Out:
# ['../models/feature_names.pkl']

# %% [markdown]
# Remove Duration Feature

# %%
# Remove duration column
df = df.drop(columns=["duration"])

print("Duration feature removed successfully.\n")

print("Updated Dataset Shape:")
print(df.shape)

print("\nRemaining Columns:")
print(df.columns.tolist())
# Out:
# Duration feature removed successfully.
#
# Updated Dataset Shape:
# (41176, 20)
#
# Remaining Columns:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y']

# %% [markdown]
# Handle Unknown Values

# %%
unknown_columns = [
    "job",
    "marital",
    "education",
    "default",
    "housing",
    "loan"
]

for col in unknown_columns:
    mode_value = df.loc[df[col] != "unknown", col].mode()[0]
    df[col] = df[col].replace("unknown", mode_value)

print("Unknown values handled successfully.\n")

for col in unknown_columns:
    print(f"{col}: {(df[col] == 'unknown').sum()} unknown values remaining")
# Out:
# Unknown values handled successfully.
#
# job: 0 unknown values remaining
# marital: 0 unknown values remaining
# education: 0 unknown values remaining
# default: 0 unknown values remaining
# housing: 0 unknown values remaining
# loan: 0 unknown values remaining

# %% [markdown]
# Save Clean Dataset

# %%
import os

os.makedirs("../src/data/processed", exist_ok=True)

df.to_csv(
    "../src/data/processed/bank_clean.csv",
    index=False
)

print("Clean dataset saved successfully.")
print("Location: ../src/data/processed/bank_clean.csv")
# Out:
# Clean dataset saved successfully.
# Location: ../src/data/processed/bank_clean.csv

# %% [markdown]
# Final Dataset Information

# %%
print("FINAL DATASET INFORMATION")

print("\nDataset Shape:")
print(df.shape)

print("\nMissing Values:")
print(df.isnull().sum().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# FINAL DATASET INFORMATION
#
# Dataset Shape:
# (41176, 20)
#
# Missing Values:
# 0
#
# Duplicate Rows:
# 2097

# %% [markdown]
# Save Preprocessed Dataset

# %%
import os

os.makedirs("../src/data/processed", exist_ok=True)

df.to_csv(
    "../src/data/processed/bank_preprocessed.csv",
    index=False
)

print("Preprocessed dataset saved successfully.")
print("Location: ../src/data/processed/bank_preprocessed.csv")
# Out:
# Preprocessed dataset saved successfully.
# Location: ../src/data/processed/bank_preprocessed.csv

# %% [markdown]
# Save Machine Learning Dataset

# %%
df.to_csv(
    "../src/data/processed/bank_ml_dataset.csv",
    index=False
)

print("Machine Learning dataset saved successfully.")
# Out:
# Machine Learning dataset saved successfully.

# %% [markdown]
# Preprocessing Summary

# %%
print("DATA PREPROCESSING COMPLETED")

print(f"Final Dataset Shape : {df.shape}")
print(f"Missing Values      : {df.isnull().sum().sum()}")
print(f"Duplicate Rows      : {df.duplicated().sum()}")
# Out:
# DATA PREPROCESSING COMPLETED
# Final Dataset Shape : (41176, 20)
# Missing Values      : 0
# Duplicate Rows      : 2097

# %% [markdown]
# Final Machine Learning Dataset

# %%
X["y"] = y.values

X.to_csv(
    "../src/data/processed/bank_ml_dataset.csv",
    index=False
)

print("Machine Learning Dataset Saved Successfully.")
print(X.shape)
# Out:
# Machine Learning Dataset Saved Successfully.
# (41176, 54)
